# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline
img = cv2.imread('data/manifest.png', 0)
template = cv2.resize(cv2.imread('data/444.png', 0), (0,0), fx=0.5, fy=0.5)
h, w = template.shape

methods = [cv2.TM_CCOEFF, cv2.TM_CCOEFF_NORMED, cv2.TM_CCORR,
           cv2.TM_CCORR_NORMED, cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]
img2 = img.copy()

result = cv2.matchTemplate(img2, template, method=methods[0])
min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(result)
location = max_loc

bottom_right = (location[0] + w, location[1] + h)
cv2.rectangle(img2, location, bottom_right, 0, 5)
plt.imshow(img2, cmap='gray')
plt.show()

# %%
bottom_right
# Out:
# (1596, 289)

# %%
crop = img2[location[1]:bottom_right[1],location[0]:bottom_right[0]]
plt.imshow(crop, cmap='gray')

# %%
# Out:
# (1357, 172)
